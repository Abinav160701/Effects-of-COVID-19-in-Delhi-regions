# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings(action='ignore')
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.formula.api as formula
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels as sm
from sklearn import preprocessing
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Lasso,Ridge
#from sklearn.externals import joblib
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from IPython.display import display
from sklearn import metrics

# %%
data = pd.read_excel (r'C:\Users\Kira\Desktop\Internship\Data\Delhi_Data-20210529T043217Z-001\Delhi_Data\2013-2020-RK-PURAM-final-dataset\3y_weekly_RKPURAM.xlsx')
data['From Date']=pd.to_datetime(data['From Date'])
data['year'] = data['From Date'].dt.year
data['month'] = data['From Date'].dt.month
data['day'] = data['From Date'].dt.day

# %%
import datetime as dt

# %%
data['From Date']= data['From Date'].map(dt.datetime.toordinal)

# %%
df=data.loc['0':'207']

# %%
df
# Out:
#      From Date     PM2.5y1       PM1y1        NOy1       NO2y1       NOxy1  \
# 0       735966  318.998571  480.381429  159.387143   95.130000  302.424286
# 1       735973  289.505714  472.055714  228.792857   84.445714  387.365714
# 2       735980  194.122857  341.192857   73.390000   73.867143  165.957143
# 3       735987  245.710000  434.321429   72.510000   88.392857  177.928571
# 4       735994  200.511429  430.995714  154.150000  100.797143  300.324286
# ..         ...         ...         ...         ...         ...         ...
# 203     737394  190.887143  351.001429  150.995714  101.784286  182.934286
# 204     737401  234.834286  415.775714  185.720000  107.428571  220.201429
# 205     737408  198.044286  325.415714  115.980000   84.142857  147.455714
# 206     737415  281.095714  430.512857  148.477143  102.625714  184.412857
# 207     737422  302.818571  428.861429  125.535714   76.847143  144.901429
#
#          NH3y1      SO2y1      COy1     Ozoney1  ...      Ozone         RH  \
# 0    82.168571  39.745714  2.932857   46.822857  ...  55.380000  60.705714
# 1    92.285714  40.324286  5.032857   45.618571  ...  37.230000  70.215714
# 2    59.112857  25.532857  2.041429   52.710000  ...  56.340000  69.085714
# 3    56.801429  28.978571  2.494286   69.548571  ...  69.467143  74.524286
# 4    66.545714  35.051429  3.425714   49.100000  ...  49.721429  66.011429
# ..         ...        ...       ...         ...  ...        ...        ...
# 203  41.087143   7.274286  2.272857   27.704286  ...  33.955714  65.341429
# 204  40.914286   6.067143  2.631429   25.794286  ...  30.771429  63.680000
# 205  39.132857  12.660000  2.165000   34.307143  ...  29.844286  71.202857
# 206  42.044286  21.525714  2.811429  101.102857  ...  21.508571  78.275714
# 207  32.607143  19.845714  2.175714   81.874286  ...  23.017143  75.128571
#
#            WS          WD         SR          BP         AT  year  month  day
# 0    0.887143  167.552857  61.578571  736.275714  12.331429  2016      1    3
# 1    0.842857  218.824286  56.858571  733.617143  12.807143  2016      1   10
# 2    1.155714  195.938571  60.500000  734.085714  11.747143  2016      1   17
# 3    0.992857  195.488571  58.688571  734.132857   8.005714  2016      1   24
# 4    0.885714  191.221429  67.075714  733.885714  12.675714  2016      1   31
# ..        ...         ...        ...         ...        ...   ...    ...  ...
# 203  0.708571  182.577143  68.381429  971.778571  15.910000  2019     12    1
# 204  0.488571  202.080000  75.555714  972.078571  12.905714  2019     12    8
# 205  0.722857  175.794286  62.701429  972.037143  17.242857  2019     12   15
# 206  0.567143  202.740000  49.167143  971.940000  12.917143  2019     12   22
# 207  0.531429  201.495714  59.994286  972.212857  10.487143  2019     12   29
#
# [208 rows x 64 columns]

# %%
df.columns
# Out:
# Index(['From Date', 'PM2.5y1', 'PM1y1', 'NOy1', 'NO2y1', 'NOxy1', 'NH3y1',
#        'SO2y1', 'COy1', 'Ozoney1', 'RHy1', 'WSy1', 'WDy1', 'SRy1', 'BPy1',
#        'ATy1', 'PM2.5y2', 'PM1y2', 'NOy2', 'NO2y2', 'NOxy2', 'NH3y2', 'SO2y2',
#        'COy2', 'Ozoney2', 'RHy2', 'WSy2', 'WDy2', 'SRy2', 'BPy2', 'ATy2',
#        'PM2.5y3', 'PM1y3', 'NOy3', 'NO2y3', 'NOxy3', 'NH3y3', 'SO2y3', 'COy3',
#        'Ozoney3', 'RHy3', 'WSy3', 'WDy3', 'SRy3', 'BPy3', 'ATy3', 'PM2.5',
#        'PM1', 'NO', 'NO2', 'NOx', 'NH3', 'SO2', 'CO', 'Ozone', 'RH', 'WS',
#        'WD', 'SR', 'BP', 'AT', 'year', 'month', 'day'],
#       dtype='object')

# %%
X1 = df[['NH3y1','NH3y2','NH3y3','year', 'month', 'day']]
Y1 = df['NH3']

# %%
X1
# Out:
#          NH3y1      NH3y2      NH3y3  year  month  day
# 0    82.168571  88.727143  88.853333  2016      1    3
# 1    92.285714  87.590000  67.077143  2016      1   10
# 2    59.112857  58.910000  84.970000  2016      1   17
# 3    56.801429  57.015714  91.982857  2016      1   24
# 4    66.545714  63.175714  86.567143  2016      1   31
# ..         ...        ...        ...   ...    ...  ...
# 203  41.087143  32.084286  32.228571  2019     12    1
# 204  40.914286  42.735714  52.100000  2019     12    8
# 205  39.132857  43.305714  45.397143  2019     12   15
# 206  42.044286  42.075000  48.005714  2019     12   22
# 207  32.607143  42.882857  56.007143  2019     12   29
#
# [208 rows x 6 columns]

# %%
xtrain=X1.loc['0':'155']
ytrain=Y1.loc['0':'155',]
xtest=X1.loc['155':'207']
ytest=Y1.loc['155':'207']

# %%
#xtrain,xtest,ytrain,ytest = train_test_split(X1,Y1,test_size=.2)

# %%
forest = RandomForestRegressor(n_estimators=2500,
                              max_depth=9,
                              max_features='auto',
                              min_samples_split=8,
                              min_samples_leaf=7,random_state=2)

forest.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(max_depth=9, min_samples_leaf=7, min_samples_split=8,
#                       n_estimators=2500, random_state=2)

# %%
# we now score the model
print('Score on train data: {}\n'.format(forest.score(xtrain,ytrain)))
print('Score on test data: {}\n'.format(forest.score(xtest,ytest)))

forest_pred = forest.predict(xtest)
forest_mse = mean_squared_error(ytest,forest_pred)
forest_accuracy = r2_score(ytest,forest_pred)

print('Root Mean Squared Error: {}\n'.format(np.sqrt(forest_mse)))
print('Overall model accuracy: {}'.format(forest_accuracy))
# Out:
# Score on train data: 0.651362387320081
#
# Score on test data: -3.854374052608251
#
# Root Mean Squared Error: 11.294952297344375
#
# Overall model accuracy: -3.854374052608251

# %%
test=data.loc['207':'259']
X=test[['NH3y1','NH3y2','NH3y3','year', 'month', 'day']]
X
# Out:
#          NH3y1      NH3y2      NH3y3  year  month  day
# 207  32.607143  42.882857  56.007143  2019     12   29
# 208  29.011429  43.077143  57.234286  2020      1    5
# 209  31.015714  35.634286  48.108571  2020      1   12
# 210  28.408571  38.150000  43.388571  2020      1   19
# 211  23.565714  34.502857  44.487143  2020      1   26
# 212  23.558571  19.232857  42.347143  2020      2    2
# 213  22.507143  38.404286  39.584286  2020      2    9
# 214  27.225714  33.808571  30.340000  2020      2   16
# 215  27.742857  39.555714  37.265714  2020      2   23
# 216  27.334286  38.014286  26.370000  2020      3    1
# 217  25.917143  32.258571  23.787143  2020      3    8
# 218  25.497143  31.635714  17.301429  2020      3   15
# 219  21.360000  30.988571  16.492857  2020      3   22
# 220  22.554286  31.171429  25.394286  2020      3   29
# 221  23.711429  37.747143  32.894286  2020      4    5
# 222  25.988571  35.204286  37.142857  2020      4   12
# 223  24.082857  30.742857  15.192857  2020      4   19
# 224  31.290000  35.092857  13.947143  2020      4   26
# 225  31.235714  39.265714  10.232857  2020      5    3
# 226  30.282857  37.304286  14.847143  2020      5   10
# 227  31.914286  35.010000  14.505714  2020      5   17
# 228  28.241429  35.450000  12.684286  2020      5   24
# 229  25.448571  49.055714  15.700000  2020      5   31
# 230  31.080000  49.998571  32.351429  2020      6    7
# 231  25.444286  33.334286  40.082857  2020      6   14
# 232  26.021429  29.692857  30.481429  2020      6   21
# 233  23.631429  47.255714  31.965714  2020      6   28
# 234  24.550000  44.368571  46.795714  2020      7    5
# 235  21.988571  37.865714  49.227143  2020      7   12
# 236  22.572857  30.662857  31.728571  2020      7   19
# 237  28.398571  15.161429  32.050000  2020      7   26
# 238  26.962857  13.777143  12.360000  2020      8    2
# 239  24.322857  14.408571  14.372857  2020      8    9
# 240  21.521429  30.641429  17.894286  2020      8   16
# 241  21.280000  14.278571  28.517143  2020      8   23
# 242  21.628571  10.180000  12.650000  2020      8   30
# 243  25.132857   7.915714  10.240000  2020      9    6
# 244  22.691429   7.135714   7.374286  2020      9   13
# 245  18.264286  16.048571   7.208571  2020      9   20
# 246  10.905714  33.008571  20.857143  2020      9   27
# 247   8.712857  42.747143  32.250000  2020     10    4
# 248  23.551429  38.767143  44.998571  2020     10   11
# 249  25.430000  42.285714  36.072857  2020     10   18
# 250  17.520000  37.975714  38.071429  2020     10   25
# 251  23.642857  33.081429  38.545714  2020     11    1
# 252  13.642857  37.248571  38.360000  2020     11    8
# 253  26.545714  49.400000  52.310000  2020     11   15
# 254  12.265714  39.484286  48.667143  2020     11   22
# 255  16.817143  41.087143  32.084286  2020     11   29
# 256  26.545714  40.914286  42.735714  2020     12    6
# 257  23.760000  39.132857  43.305714  2020     12   13
# 258  28.432857  42.044286  42.075000  2020     12   20
# 259  28.827143  32.607143  42.882857  2020     12   27

# %%
predict=forest.predict(X)

# %%
predict
# Out:
# array([39.64114931, 35.15543743, 35.27288665, 32.00528886, 31.31461828,
#        28.40732398, 33.9926253 , 30.42615007, 30.57529597, 33.26311924,
#        32.79825814, 30.26722242, 28.66297072, 28.52958796, 32.99805362,
#        31.95123589, 28.6303091 , 30.68221164, 35.70695947, 35.72290203,
#        31.21495187, 30.16057374, 30.71415614, 36.98200836, 32.57620274,
#        29.20455751, 31.35687218, 35.0295808 , 33.43854699, 28.86224883,
#        25.83328159, 19.83904137, 18.63636416, 21.48124213, 20.31676429,
#        20.36961738, 18.70014987, 17.69595393, 18.812458  , 22.9952272 ,
#        31.38134614, 33.47323044, 33.02273713, 32.02199073, 32.2367735 ,
#        31.71337267, 34.36794957, 33.50369569, 32.15504918, 35.19244232,
#        33.92634269, 35.60356811, 36.098141  ])

# %%
dates=data.loc['207':'259','From Date']

# %%
dates
# Out:
# 207    737422
# 208    737429
# 209    737436
# 210    737443
# 211    737450
# 212    737457
# 213    737464
# 214    737471
# 215    737478
# 216    737485
# 217    737492
# 218    737499
# 219    737506
# 220    737513
# 221    737520
# 222    737527
# 223    737534
# 224    737541
# 225    737548
# 226    737555
# 227    737562
# 228    737569
# 229    737576
# 230    737583
# 231    737590
# 232    737597
# 233    737604
# 234    737611
# 235    737618
# 236    737625
# 237    737632
# 238    737639
# 239    737646
# 240    737653
# 241    737660
# 242    737667
# 243    737674
# 244    737681
# 245    737688
# 246    737695
# 247    737702
# 248    737709
# 249    737716
# 250    737723
# 251    737730
# 252    737737
# 253    737744
# 254    737751
# 255    737758
# 256    737765
# 257    737772
# 258    737779
# 259    737786
# Name: From Date, dtype: int64

# %%
X['From Date']=dates.values

# %%
X.columns
# Out:
# Index(['NH3y1', 'NH3y2', 'NH3y3', 'year', 'month', 'day', 'From Date'], dtype='object')

# %%
X['From Date']= X['From Date'].map(dt.datetime.fromordinal)

# %%
test['From Date']= test['From Date'].map(dt.datetime.fromordinal)

# %%
test = test.set_index(['From Date'])
X = X.set_index(['From Date'])

# %%
X['pred']=predict

# %%
test['NH3'].plot(legend=True, label='Actual NH3', figsize=(10,6))
X['pred'].plot(legend=True, label='Predicted NH3')
# Out:
# <AxesSubplot:xlabel='From Date'>

# %%
np.sqrt(mean_squared_error(test['NH3'],X['pred']))
# Out:
# 12.156778392256829

# %%
mae = metrics.mean_absolute_error(ytest, forest_pred)
mse = metrics.mean_squared_error(ytest, forest_pred)
rmsetest = np.sqrt(mse) # or mse**(0.5)  
r2 = metrics.r2_score(ytest,forest_pred)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmsetest)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 9.094208441304415
# MSE: 127.57594739928497
# RMSE: 11.294952297344375
# R-Squared: -3.854374052608251

# %%
mae = metrics.mean_absolute_error(test['NH3'],X['pred'])
mse = metrics.mean_squared_error(test['NH3'],X['pred'])
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = metrics.r2_score(test['NH3'],X['pred'])

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 10.51030987957841
# MSE: 147.78726087844254
# RMSE: 12.156778392256829
# R-Squared: -1.3277733359510044

# %%
import pickle
filename = 'NH3_forest3y.sav'
pickle.dump(forest, open(filename, 'wb'))

# %%
#load model
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(xtest, ytest)
print(result)
# Out:
# -3.854374052608251

# %% [markdown]
# # 3rd plot

# %%
testcase = pd.DataFrame()

# %%
testcase['test']=ytest
testcase['pred']=forest_pred

# %%
testcase["Corrected"] = np.where(testcase["pred"]<testcase["test"],testcase["pred"]+rmsetest ,
                   np.where(testcase["pred"]>testcase["test"], testcase["pred"]-rmsetest,
                            testcase["pred"]))

# %%
testcase['test'].plot(legend=True, label='Actual NH3', figsize=(10,6))
testcase['pred'].plot(legend=True, label='Predicted NH3')
testcase["Corrected"].plot(legend=True, label='Corrected NH3')
# Out:
# <AxesSubplot:>

# %%
r2 = metrics.r2_score(testcase["Corrected"],testcase['test'])
r2
# Out:
# -0.0033162532482642337

# %%
test2020=pd.DataFrame()

# %%
test2020['test']=test['NH3']
test2020['pred']=X['pred']

# %%
test2020.index=test.index

# %%
test2020["Corrected"] = np.where(test2020["pred"]<test2020["test"],test2020["pred"]+rmsetest ,
                   np.where(test2020["pred"]>test2020["test"], test2020["pred"]-rmsetest,
                            test2020["pred"]))

# %%
test2020['test'].plot(legend=True, label='Actual PM2.5', figsize=(10,6))
test2020['pred'].plot(legend=True, label='Predicted PM2.5')
test2020["Corrected"].plot(legend=True, label='Corrected PM2.5')
# Out:
# <AxesSubplot:xlabel='From Date'>

# %%
r2020 = metrics.r2_score(test2020["Corrected"],test2020['test'])
r2020
# Out:
# 0.1909589653262903
